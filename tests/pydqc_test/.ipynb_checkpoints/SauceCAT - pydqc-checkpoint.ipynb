# %%
import pydqc
import pandas as pd
# libraries to avoid errors
import joblib
import sys

# %%
df = pd.read_csv("Tables Joined/Sales Orders anonymized.csv")
# Out:
# C:\Users\51917\AppData\Local\Temp\ipykernel_36288\4017450075.py:1: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Tables Joined/Sales Orders anonymized.csv")

# %%
sys.modules['sklearn.externals.joblib'] = joblib

# %%
from pydqc import infer_schema

# %%
# create table schema if you haven't already
infer_schema.infer_schema(df, "Sales Orders Anonymized", sample_size=1.0, type_threshold=0.5, n_jobs=1, base_schema=None)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 infer_schema.infer_schema(df, "Sales Orders Anonymized", output_root='pydqc outputs', sample_size=1.0, type_threshold=0.5, n_jobs=1, base_schema=None)
#
# File E:\anaconda3\lib\site-packages\pydqc-0.1.0-py3.10.egg\pydqc\infer_schema.py:195, in infer_schema(data, fname, output_root, sample_size, type_threshold, n_jobs, base_schema)
#     192     data_types[col] = type_infos_df.loc[type_infos_df['column']==col, 'type'].values[0]
#     194 # get basic statistic information for all columns
# --> 195 stat_infos = Parallel(n_jobs=_n_jobs)(delayed(_cal_column_stat)
#     196     (data_dropna_sample_values[col], col, data_types[col]) for col in data.columns.values)
#     197 stat_infos_df = pd.DataFrame(stat_infos)
#     199 # merge dtype infomation with stat information
#
# ...

# %%
from pydqc import data_summary

# %%
import pandas as pd
import numpy as np

import datetime

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("white")

# %matplotlib inline

from pydqc.data_summary import distribution_summary_pretty

# %%
table_schema = pd.read_excel("pydqc outputs/data_schema_Sales Orders Anonymized.xlsx")
data_summary.data_summary(table_schema,df, "Sales Orders Anonymized")

# %%
# the data table (pandas DataFrame)
table =df
print("table size: " + str(table.shape))

# global values
VER_LINE = "#4BACC6"
TEXT_LIGHT = "#DAEEF3"
DIS_LINE = "#F79646"

# get date of today
snapshot_date_now = str(datetime.datetime.now().date())
print("date of today: " + snapshot_date_now)
# Out:
# table size: (1976212, 17)
# date of today: 2023-11-27

# %%
df.head()
# Out:
#    DOMU DOWH         DOWHD  DOSTKY  DOSTMU  DOORD#  DOSUFX    DOPART  DOQTY  \
# 0    31   NL  WarehouseNL1  312160      30  100068       2  SKU71623      1
# 1    31   NL  WarehouseNL1  334000      33  100076       0  SKU45337      1
# 2    31   NL  WarehouseNL1  32A600      33  100132       0  SKU41144      2
# 3    31   NL  WarehouseNL1  32A600      33  100132       0  SKU41145      1
# 4    31   NL  WarehouseNL1  32A600      33  100132       0  SKU41151      1
#
#   DOSUM DOORIG DODTYP  DODYMD   DOSVAL DOCURC DOCUST    VALUE €
# 0    EA    NaN    NaN  220411   0.0075     EU    NaN   0.006919
# 1    PR    NaN    NaN  220113  16.3875     EU    NaN  15.117469
# 2    EA  OASIS      Y  220304  24.1425     EU    NaN  22.271456
# 3    EA  OASIS      Y  220304  12.0750     EU    NaN  11.139188
# 4    EA  OASIS      Y  220304  12.0750     EU    NaN  11.139188

# %%
df.fillna("NULL",inplace=True)

# %%
# another way to show the plots without the table schema
distribution_summary_pretty(df, "VALUE €", figsize=None, date_flag=False)
